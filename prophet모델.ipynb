# %%
import pandas as pd
import numpy as np

data = pd.read_csv("/content/drive/MyDrive/SWIG/보성군_AWS_및_기상_변수선정_및_전처리본_Eng.csv")

columns_to_convert = data.columns[data.columns != 'ds']
data[columns_to_convert] = data[columns_to_convert].astype(float)

# %%
print(data['y'].describe())
# Out:
# count    3768.000000
# mean       22.829442
# std        12.197139
# min         0.535856
# 25%        12.841180
# 50%        20.805655
# 75%        32.172835
# max        62.995488
# Name: y, dtype: float64

# %%
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from prophet import Prophet

data['y'] = np.log(data['y'])

# 훈련 데이터셋과 테스트 데이터셋으로 나누기
train_df, test_df = train_test_split(data, test_size=0.2, shuffle=False)

# 하이퍼파라미터 그리드를 정의합니다.
param_grid = {
    'changepoint_prior_scale': [0.001, 0.01, 0.1, 0.5],
    'seasonality_prior_scale': [0.01, 0.1, 1.0, 10.0],
    'holidays_prior_scale': [0.01, 0.1, 1.0, 10.0]
}

# 최적의 하이퍼파라미터와 그 때의 RMSE를 저장할 변수를 초기화합니다.
best_params = None
best_rmse = np.inf

# 모든 하이퍼파라미터 조합에 대해 탐색을 수행합니다.
for changepoint_prior_scale in param_grid['changepoint_prior_scale']:
    for seasonality_prior_scale in param_grid['seasonality_prior_scale']:
        for holidays_prior_scale in param_grid['holidays_prior_scale']:
            # 모델을 생성하고 학습합니다.
            model = Prophet(changepoint_prior_scale=changepoint_prior_scale,
                            seasonality_prior_scale=seasonality_prior_scale,
                            holidays_prior_scale=holidays_prior_scale)
            model.add_regressor('AvgT')
            model.add_regressor('MaxWdSd')
            model.add_regressor('AvgHu')
            model.add_regressor('Sum_DL')
            model.add_regressor('50CM_SM')
            model.add_regressor('Avg_GT')
            model.add_regressor('Avg_IM')
            model.add_regressor('Rain')
            model.fit(train_df)

            # 예측을 수행합니다.
            future = model.make_future_dataframe(periods=len(test_df), freq='D', include_history=True)
            for col in columns_to_convert:
                if col != 'y':
                    future[col] = data[col]
            forecast = model.predict(future)

            # RMSE를 계산합니다.
            rmse = np.sqrt(mean_squared_error(np.exp(test_df['y']), np.exp(forecast.iloc[-len(test_df):]['yhat'])))

            # 현재의 하이퍼파라미터가 더 좋은 성능을 보이면, 최적의 하이퍼파라미터를 업데이트합니다.
            if rmse < best_rmse:
                best_params = {'changepoint_prior_scale': changepoint_prior_scale,
                               'seasonality_prior_scale': seasonality_prior_scale,
                               'holidays_prior_scale': holidays_prior_scale}
                best_rmse = rmse

# 최적의 하이퍼파라미터와 그 때의 RMSE를 출력합니다.
print("최적의 하이퍼파라미터:", best_params)
print("최적의 RMSE:", best_rmse)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/rcl8d6xb.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/5ejzaf4r.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=75175', 'data', 'file=/tmp/tmpiv_prys6/rcl8d6xb.json', 'init=/tmp/tmpiv_prys6/5ejzaf4r.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelq5fxfn_y/prophet_model-20231031075301.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:53:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:53:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/ca28jyrb.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/wlt27dwd.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28360', 'data', 'file=/tmp/tmpiv_prys6/ca28jyrb.json', 'init=/tmp/tmpiv_prys6/wlt27dwd.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelfxt6ki9n/prophet_model-20231031075303.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:53:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:53:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/hd05p29m.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/38j85qv3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28513', 'data', 'file=/tmp/tmpiv_prys6/hd05p29m.json', 'init=/tmp/tmpiv_prys6/38j85qv3.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelrq32skd6/prophet_model-20231031075305.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:53:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:53:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/fx41vcx8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/veejop19.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=42405', 'data', 'file=/tmp/tmpiv_prys6/fx41vcx8.json', 'init=/tmp/tmpiv_prys6/veejop19.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelmr5lbhij/prophet_model-20231031075309.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:53:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:53:10 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/qadclzx1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/g6j12q9a.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=55022', 'data', 'file=/tmp/tmpiv_prys6/qadclzx1.json', 'init=/tmp/tmpiv_prys6/g6j12q9a.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modeln5fj_peg/prophet_model-20231031075314.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:53:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:53:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/dxqf7w00.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/9kzjfmzh.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=24856', 'data', 'file=/tmp/tmpiv_prys6/dxqf7w00.json', 'init=/tmp/tmpiv_prys6/9kzjfmzh.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelhw62edom/prophet_model-20231031075318.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:53:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:53:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/dynfysq4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/l89muhes.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=29735', 'data', 'file=/tmp/tmpiv_prys6/dynfysq4.json', 'init=/tmp/tmpiv_prys6/l89muhes.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_model3ly0fnuv/prophet_model-20231031075320.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:53:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:53:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/w49nxl14.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/o79mtuoa.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=33479', 'data', 'file=/tmp/tmpiv_prys6/w49nxl14.json', 'init=/tmp/tmpiv_prys6/o79mtuoa.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelfyrwn470/prophet_model-20231031075321.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:53:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:53:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/elttjequ.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/7mbs7gqw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=93405', 'data', 'file=/tmp/tmpiv_prys6/elttjequ.json', 'init=/tmp/tmpiv_prys6/7mbs7gqw.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelp73dp26e/prophet_model-20231031075323.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:53:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:53:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/of6d_676.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/zpm_3u51.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=5713', 'data', 'file=/tmp/tmpiv_prys6/of6d_676.json', 'init=/tmp/tmpiv_prys6/zpm_3u51.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelaczhn4xr/prophet_model-20231031075325.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:53:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:53:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/fbcyj2i5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/7cj911ku.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=40429', 'data', 'file=/tmp/tmpiv_prys6/fbcyj2i5.json', 'init=/tmp/tmpiv_prys6/7cj911ku.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modellvd1_a33/prophet_model-20231031075328.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:53:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:53:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/9ifaspu_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/x_qar_wr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=7950', 'data', 'file=/tmp/tmpiv_prys6/9ifaspu_.json', 'init=/tmp/tmpiv_prys6/x_qar_wr.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelhkejk5k4/prophet_model-20231031075329.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:53:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:53:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/9phio6sz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/n0sazxyl.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=7636', 'data', 'file=/tmp/tmpiv_prys6/9phio6sz.json', 'init=/tmp/tmpiv_prys6/n0sazxyl.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelg9qg1g0l/prophet_model-20231031075331.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:53:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:53:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/kox3tgag.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/mnerlw9g.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=31582', 'data', 'file=/tmp/tmpiv_prys6/kox3tgag.json', 'init=/tmp/tmpiv_prys6/mnerlw9g.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelfbkrn_gp/prophet_model-20231031075333.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:53:33 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:53:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/fn0t6f8v.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/d3x2c6b_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85355', 'data', 'file=/tmp/tmpiv_prys6/fn0t6f8v.json', 'init=/tmp/tmpiv_prys6/d3x2c6b_.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelre90ylo_/prophet_model-20231031075335.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:53:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:53:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/whsol6tf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/8mp96jaw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62169', 'data', 'file=/tmp/tmpiv_prys6/whsol6tf.json', 'init=/tmp/tmpiv_prys6/8mp96jaw.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_model7z_7vu8y/prophet_model-20231031075336.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:53:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:53:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/c7uqg3lc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/h2ycicbl.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=50065', 'data', 'file=/tmp/tmpiv_prys6/c7uqg3lc.json', 'init=/tmp/tmpiv_prys6/h2ycicbl.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelafcvitk3/prophet_model-20231031075338.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:53:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:53:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/bwlbym99.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/215_1_xx.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56126', 'data', 'file=/tmp/tmpiv_prys6/bwlbym99.json', 'init=/tmp/tmpiv_prys6/215_1_xx.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelpmfzealo/prophet_model-20231031075341.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:53:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:53:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/0c0g6ak7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/vd0jw0xj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=17373', 'data', 'file=/tmp/tmpiv_prys6/0c0g6ak7.json', 'init=/tmp/tmpiv_prys6/vd0jw0xj.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelpgz2s0hf/prophet_model-20231031075343.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:53:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:53:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/psn_6cyn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/hx7y4l19.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=45403', 'data', 'file=/tmp/tmpiv_prys6/psn_6cyn.json', 'init=/tmp/tmpiv_prys6/hx7y4l19.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_model41keyek0/prophet_model-20231031075345.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:53:45 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:53:46 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/hb0bs2oy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/odnzewfe.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=35768', 'data', 'file=/tmp/tmpiv_prys6/hb0bs2oy.json', 'init=/tmp/tmpiv_prys6/odnzewfe.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelqu4dc451/prophet_model-20231031075347.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:53:47 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:53:48 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/kk54zrb4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/shk3qr6o.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=95399', 'data', 'file=/tmp/tmpiv_prys6/kk54zrb4.json', 'init=/tmp/tmpiv_prys6/shk3qr6o.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelukaxe2bs/prophet_model-20231031075349.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:53:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:53:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/wzu_u_rb.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/r15fu95h.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=78408', 'data', 'file=/tmp/tmpiv_prys6/wzu_u_rb.json', 'init=/tmp/tmpiv_prys6/r15fu95h.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelxy3y1ow0/prophet_model-20231031075351.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:53:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:53:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/ggju5khg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/9jlu_hln.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=6782', 'data', 'file=/tmp/tmpiv_prys6/ggju5khg.json', 'init=/tmp/tmpiv_prys6/9jlu_hln.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelvju66n39/prophet_model-20231031075353.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:53:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:53:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/80wmpirf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/3ycpmwfk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=94950', 'data', 'file=/tmp/tmpiv_prys6/80wmpirf.json', 'init=/tmp/tmpiv_prys6/3ycpmwfk.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_model9dbpnia0/prophet_model-20231031075356.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:53:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:53:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/j2fihyab.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/g7ch73gf.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=22684', 'data', 'file=/tmp/tmpiv_prys6/j2fihyab.json', 'init=/tmp/tmpiv_prys6/g7ch73gf.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelon3uygzq/prophet_model-20231031075358.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:53:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:53:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/9z18ins1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/x3y7xcxm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=79071', 'data', 'file=/tmp/tmpiv_prys6/9z18ins1.json', 'init=/tmp/tmpiv_prys6/x3y7xcxm.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_model4eh41qid/prophet_model-20231031075400.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:54:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:54:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/kxb4iqp_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/592jyyhj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=84839', 'data', 'file=/tmp/tmpiv_prys6/kxb4iqp_.json', 'init=/tmp/tmpiv_prys6/592jyyhj.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modeljsf7qd7h/prophet_model-20231031075402.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:54:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:54:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/ktrtpa3s.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/qs73ozp3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=76832', 'data', 'file=/tmp/tmpiv_prys6/ktrtpa3s.json', 'init=/tmp/tmpiv_prys6/qs73ozp3.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelh6isfak_/prophet_model-20231031075404.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:54:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:54:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/_ohg7lsl.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/scrdnbu4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=40289', 'data', 'file=/tmp/tmpiv_prys6/_ohg7lsl.json', 'init=/tmp/tmpiv_prys6/scrdnbu4.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelbz7diiaw/prophet_model-20231031075406.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:54:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:54:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/s0radq9f.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/pg6f0zgy.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=37032', 'data', 'file=/tmp/tmpiv_prys6/s0radq9f.json', 'init=/tmp/tmpiv_prys6/pg6f0zgy.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelh_8aq5pi/prophet_model-20231031075408.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:54:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:54:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/kqsla3or.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/e5wokct3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=29259', 'data', 'file=/tmp/tmpiv_prys6/kqsla3or.json', 'init=/tmp/tmpiv_prys6/e5wokct3.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelfbe25xgi/prophet_model-20231031075410.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:54:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:54:11 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/kb9i9lcw.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/n1sknlid.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=49187', 'data', 'file=/tmp/tmpiv_prys6/kb9i9lcw.json', 'init=/tmp/tmpiv_prys6/n1sknlid.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelu62bbvuc/prophet_model-20231031075413.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:54:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:54:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/qn0dnjt_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/mbih_9b2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=73629', 'data', 'file=/tmp/tmpiv_prys6/qn0dnjt_.json', 'init=/tmp/tmpiv_prys6/mbih_9b2.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelixcnr1_2/prophet_model-20231031075415.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:54:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:54:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/tgqgp6yq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/tj7deuch.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=48678', 'data', 'file=/tmp/tmpiv_prys6/tgqgp6yq.json', 'init=/tmp/tmpiv_prys6/tj7deuch.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelvv0y499e/prophet_model-20231031075417.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:54:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:54:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/zrj_tc76.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/a8efhbc7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=90495', 'data', 'file=/tmp/tmpiv_prys6/zrj_tc76.json', 'init=/tmp/tmpiv_prys6/a8efhbc7.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelx8co20fv/prophet_model-20231031075420.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:54:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:54:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/bpuhmt0e.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/c1dnewta.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=17625', 'data', 'file=/tmp/tmpiv_prys6/bpuhmt0e.json', 'init=/tmp/tmpiv_prys6/c1dnewta.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modeln8gk3s8l/prophet_model-20231031075423.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:54:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:54:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/x9_tklag.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/ajwj154t.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59505', 'data', 'file=/tmp/tmpiv_prys6/x9_tklag.json', 'init=/tmp/tmpiv_prys6/ajwj154t.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_model1ofcccqy/prophet_model-20231031075426.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:54:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:54:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/to9a11qo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/5dm413ov.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=2219', 'data', 'file=/tmp/tmpiv_prys6/to9a11qo.json', 'init=/tmp/tmpiv_prys6/5dm413ov.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelf98llvwo/prophet_model-20231031075429.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:54:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:54:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/z2bggq7h.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/weqi04ym.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=77391', 'data', 'file=/tmp/tmpiv_prys6/z2bggq7h.json', 'init=/tmp/tmpiv_prys6/weqi04ym.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modell0lefac2/prophet_model-20231031075431.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:54:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:54:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/jtnb4zp5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/hk6uzgn2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=68671', 'data', 'file=/tmp/tmpiv_prys6/jtnb4zp5.json', 'init=/tmp/tmpiv_prys6/hk6uzgn2.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_model0dos5efx/prophet_model-20231031075434.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:54:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:54:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/r_wcvcsn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/f1cu_mcj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=87549', 'data', 'file=/tmp/tmpiv_prys6/r_wcvcsn.json', 'init=/tmp/tmpiv_prys6/f1cu_mcj.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_model_fq1ewe4/prophet_model-20231031075437.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:54:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:54:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/kdzadqyf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/pv3popn7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99710', 'data', 'file=/tmp/tmpiv_prys6/kdzadqyf.json', 'init=/tmp/tmpiv_prys6/pv3popn7.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelkm6h0006/prophet_model-20231031075441.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:54:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:54:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/v22du44z.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/jf5qedji.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59731', 'data', 'file=/tmp/tmpiv_prys6/v22du44z.json', 'init=/tmp/tmpiv_prys6/jf5qedji.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelmgf3p5jn/prophet_model-20231031075443.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:54:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:54:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/z92a36_4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/cwqw9gd2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=68519', 'data', 'file=/tmp/tmpiv_prys6/z92a36_4.json', 'init=/tmp/tmpiv_prys6/cwqw9gd2.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelxjhoyu_g/prophet_model-20231031075446.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:54:46 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:54:47 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/juvrr4sf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/l4_alkfc.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=11045', 'data', 'file=/tmp/tmpiv_prys6/juvrr4sf.json', 'init=/tmp/tmpiv_prys6/l4_alkfc.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_model7lxx71l7/prophet_model-20231031075449.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:54:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:54:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/bme9nvcu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/bx3vp0ku.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=83948', 'data', 'file=/tmp/tmpiv_prys6/bme9nvcu.json', 'init=/tmp/tmpiv_prys6/bx3vp0ku.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelpfphkj6w/prophet_model-20231031075451.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:54:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:54:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/y7wl3g14.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/pp0hpn_q.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=92604', 'data', 'file=/tmp/tmpiv_prys6/y7wl3g14.json', 'init=/tmp/tmpiv_prys6/pp0hpn_q.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelvmhgrfj5/prophet_model-20231031075455.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:54:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:54:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/e3luv4r4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/2gy2g9lg.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=33260', 'data', 'file=/tmp/tmpiv_prys6/e3luv4r4.json', 'init=/tmp/tmpiv_prys6/2gy2g9lg.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_model9p5nva2w/prophet_model-20231031075457.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:54:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:54:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/onfmku5p.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/5ulzxaaw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=38701', 'data', 'file=/tmp/tmpiv_prys6/onfmku5p.json', 'init=/tmp/tmpiv_prys6/5ulzxaaw.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_model6h6pp0fq/prophet_model-20231031075501.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:55:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:55:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/px02fy3h.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/vppqhzcx.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=35761', 'data', 'file=/tmp/tmpiv_prys6/px02fy3h.json', 'init=/tmp/tmpiv_prys6/vppqhzcx.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_models6xob_lo/prophet_model-20231031075504.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:55:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:55:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/4fvp8n9s.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/um77q537.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=89844', 'data', 'file=/tmp/tmpiv_prys6/4fvp8n9s.json', 'init=/tmp/tmpiv_prys6/um77q537.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelgiprheaj/prophet_model-20231031075508.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:55:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:55:10 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/y20nsw6k.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/ou6ljx46.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=4807', 'data', 'file=/tmp/tmpiv_prys6/y20nsw6k.json', 'init=/tmp/tmpiv_prys6/ou6ljx46.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_model4d83jo_j/prophet_model-20231031075512.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:55:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:55:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/rsemg66c.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/a_gpppkb.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62249', 'data', 'file=/tmp/tmpiv_prys6/rsemg66c.json', 'init=/tmp/tmpiv_prys6/a_gpppkb.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_model8okq0vzh/prophet_model-20231031075515.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:55:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:55:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/m5fmhw7e.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/5535lhfz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=68286', 'data', 'file=/tmp/tmpiv_prys6/m5fmhw7e.json', 'init=/tmp/tmpiv_prys6/5535lhfz.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modeln4f78yk4/prophet_model-20231031075519.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:55:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:55:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/r2xs__cm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/__eo_rw7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=80862', 'data', 'file=/tmp/tmpiv_prys6/r2xs__cm.json', 'init=/tmp/tmpiv_prys6/__eo_rw7.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_model5op03n4f/prophet_model-20231031075524.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:55:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:55:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/1pbuv4ag.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/sh4sf7wn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59867', 'data', 'file=/tmp/tmpiv_prys6/1pbuv4ag.json', 'init=/tmp/tmpiv_prys6/sh4sf7wn.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modeluhi9atv4/prophet_model-20231031075528.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:55:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:55:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/t8h518ny.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/v5_p270f.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=5698', 'data', 'file=/tmp/tmpiv_prys6/t8h518ny.json', 'init=/tmp/tmpiv_prys6/v5_p270f.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelosy0fby8/prophet_model-20231031075531.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:55:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:55:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/_jdrjj7e.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/njarolyc.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=15432', 'data', 'file=/tmp/tmpiv_prys6/_jdrjj7e.json', 'init=/tmp/tmpiv_prys6/njarolyc.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_model_dvsiv40/prophet_model-20231031075535.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:55:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:55:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/ck97xj2o.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/t8h87c20.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=54934', 'data', 'file=/tmp/tmpiv_prys6/ck97xj2o.json', 'init=/tmp/tmpiv_prys6/t8h87c20.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelmy4vx136/prophet_model-20231031075540.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:55:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:55:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/2boab7b2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/1nddx443.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=70299', 'data', 'file=/tmp/tmpiv_prys6/2boab7b2.json', 'init=/tmp/tmpiv_prys6/1nddx443.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modeln9wlspaz/prophet_model-20231031075543.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:55:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:55:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/0tvtjv5k.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/i8fuszyy.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=77903', 'data', 'file=/tmp/tmpiv_prys6/0tvtjv5k.json', 'init=/tmp/tmpiv_prys6/i8fuszyy.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_model3cn6nqqw/prophet_model-20231031075546.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:55:46 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:55:48 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/133x3wo0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/nvc329z5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=33292', 'data', 'file=/tmp/tmpiv_prys6/133x3wo0.json', 'init=/tmp/tmpiv_prys6/nvc329z5.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelm45oo_yc/prophet_model-20231031075550.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:55:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:55:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/_b9uow9c.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiv_prys6/bhkkoqq7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=73931', 'data', 'file=/tmp/tmpiv_prys6/_b9uow9c.json', 'init=/tmp/tmpiv_prys6/bhkkoqq7.json', 'output', 'file=/tmp/tmpiv_prys6/prophet_modelp2qyo8vo/prophet_model-20231031075554.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:55:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:55:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 최적의 하이퍼파라미터: {'changepoint_prior_scale': 0.001, 'seasonality_prior_scale': 1.0, 'holidays_prior_scale': 0.01}
# 최적의 RMSE: 3.529711374289229

# %%
from sklearn.model_selection import train_test_split
from prophet import Prophet

data['y'] = np.log(data['y'])

# 훈련 데이터셋과 테스트 데이터셋으로 나누기
train_df, test_df = train_test_split(data, test_size=0.2, shuffle=False)

# 모델 생성 및 학습
model = Prophet(changepoint_prior_scale=0.001, seasonality_prior_scale=1.0, holidays_prior_scale=0.1)
model.add_regressor('AvgT')
model.add_regressor('MaxWdSd')
model.add_regressor('AvgHu')
model.add_regressor('Sum_DL')
model.add_regressor('50CM_SM')
model.add_regressor('Avg_GT')
model.add_regressor('Avg_IM')
model.add_regressor('Rain')
model.fit(train_df)


# 예측할 기간 설정 및 예측 실행
future = model.make_future_dataframe(periods=len(test_df), freq='D', include_history=True)
for col in columns_to_convert:
    if col != 'y':
        future[col] = data[col]

forecast = model.predict(future)

# # 결과 확인
# model.plot(forecast)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbmjc47tn/d7tkqwsa.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbmjc47tn/fn29cqlj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=2679', 'data', 'file=/tmp/tmpbmjc47tn/d7tkqwsa.json', 'init=/tmp/tmpbmjc47tn/fn29cqlj.json', 'output', 'file=/tmp/tmpbmjc47tn/prophet_model39n72akw/prophet_model-20231031081341.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:13:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:13:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
from math import sqrt

# 실제값과 예측값을 원래 스케일로 변환
y_true = np.exp(test_df['y'])
y_pred = np.exp(forecast['yhat'][train_df.shape[0]:])

# MAE 계산
mae = mean_absolute_error(y_true, y_pred)
print('MAE: ', mae)

# MSE 계산
mse = mean_squared_error(y_true, y_pred)
print('MSE: ', mse)

# RMSE 계산
rmse = sqrt(mse)
print('RMSE: ', rmse)

# MAPE 계산
mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
print('MAPE: ', mape)
# Out:
# MAE:  2.772598578872633
# MSE:  13.708347238998238
# RMSE:  3.702478526473616
# MAPE:  17.239754456510052

# %% [markdown]
# 비지도학습 모델 이상치 탐지법

# %%
from sklearn.ensemble import IsolationForest
from sklearn.model_selection import ParameterGrid
import numpy as np

# 데이터셋을 준비합니다.
X = pd.read_csv("/content/drive/MyDrive/SWIG/보성군_AWS_및_기상_변수선정_및_전처리본_Eng.csv")

columns_to_convert = X.columns[X.columns != 'ds']
X[columns_to_convert] = X[columns_to_convert].astype(float)

X = X.set_index('ds')

# 탐색할 'contamination' 파라미터 후보들을 정의합니다.
param_grid = {
    'contamination': [0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008, 0.009, 0.01, 0.011, 0.012, 0.013, 0.014, 0.015, 0.016, 0.017, 0.018, 0.019, 0.02]  # 예시 값입니다. 실제로는 문제에 맞게 설정해야 합니다.
}

# 파라미터 그리드를 생성합니다.
grid = ParameterGrid(param_grid)

best_score = np.inf
best_params = None

# 각 파라미터 조합에 대해 모델을 학습하고 성능을 평가합니다.
for params in grid:
    model = IsolationForest(contamination=params['contamination'])
    model.fit(X)
    score = -model.decision_function(X).mean()  # 더 낮은 점수가 더 좋은 성능을 의미합니다.
    if score < best_score:
        best_score = score
        best_params = params

# 최적의 'contamination' 파라미터 값과 그 때의 성능을 출력합니다.
print("최적의 'contamination' 파라미터 값:", best_params)
print("최적의 성능:", best_score)

# %%
from sklearn.ensemble import IsolationForest

# IsolationForest 모델 생성
clf = IsolationForest(contamination=0.002)  # contamination은 이상치의 비율을 나타냅니다.

# 'y' 컬럼에 대해 IsolationForest 모델 학습 및 예측
clf.fit(data[['y']])
pred = clf.predict(data[['y']])

# 이상치를 -1로, 정상 데이터를 1로 표시합니다.
data['anomaly'] = pred

# 이상치 확인
outliers = data[data['anomaly'] == -1]
print(outliers)
